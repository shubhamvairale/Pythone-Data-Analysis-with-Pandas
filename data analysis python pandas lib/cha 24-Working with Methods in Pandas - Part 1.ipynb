# %% [markdown]
# # Working with Methods in Pandas - Part 1

# %%
import pandas as pd 
import numpy as np

# %%
date=pd.date_range(
    start="2018",end="2019", freq="BM")

# %%
ts=pd.Series(
    np.random.randn(len(date)),index=date)
ts
# Out:
# 2018-01-31    1.116808
# 2018-02-28   -0.078621
# 2018-03-30   -0.567434
# 2018-04-30   -0.272745
# 2018-05-31   -1.363262
# 2018-06-29   -0.536601
# 2018-07-31   -0.075388
# 2018-08-31   -0.173037
# 2018-09-28    0.050605
# 2018-10-31   -2.052347
# 2018-11-30   -0.958775
# 2018-12-31   -0.602580
# Freq: BM, dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31', '2018-06-29', '2018-07-31', '2018-08-31',
#                '2018-09-28', '2018-10-31', '2018-11-30', '2018-12-31'],
#               dtype='datetime64[ns]', freq='BM')

# %%
ts[:5].index
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-30', '2018-04-30',
#                '2018-05-31'],
#               dtype='datetime64[ns]', freq='BM')

# %% [markdown]
# ## Reading a Time Series Data Set

# %%
movie=pd.read_csv(r'C:\Users\Lenovo\Downloads\disney_plus_titles.csv')

# %%
movie.head()
# Out:
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# 4  Benjamin Valic, Lily Sanfelippo, Jakari Fraser...          United States
#
# ...

# %% [markdown]
# ## Converting date to index

# %%
movie.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
movie=pd.read_csv(r'C:\Users\Lenovo\Downloads\disney_plus_titles.csv', parse_dates=["date_added"])

# %%
movie=pd.read_csv(r'C:\Users\Lenovo\Downloads\disney_plus_titles.csv', 
    parse_dates=["date_added"], 
    index_col="date_added")

# %%
movie.index
# Out:
# DatetimeIndex(['2021-09-24', '2021-09-24', '2021-09-24', '2021-09-22',
#                '2021-09-22', '2021-09-22', '2021-09-17', '2021-09-17',
#                '2021-09-17', '2021-09-17',
#                ...
#                '2019-10-01', '2019-10-01', '2019-10-01', '2019-10-01',
#                '2019-10-01', '2019-10-01', '2019-10-01',        'NaT',
#                       'NaT',        'NaT'],
#               dtype='datetime64[ns]', name='date_added', length=1368, freq=None)

# %%
movie.head()
# Out:
#            show_id     type                           title  \
# date_added
# 2021-09-24      s1    Movie                   A Spark Story
# 2021-09-24      s2    Movie                  Spooky Buddies
# 2021-09-24      s3    Movie          The Fault in Our Stars
# 2021-09-22      s4  TV Show                 Dog: Impossible
# 2021-09-22      s5  TV Show  Spidey And His Amazing Friends
#
#                               director  \
# date_added
# 2021-09-24  Jason Sterman, Leanne Dare
# 2021-09-24                Robert Vince
# 2021-09-24                  Josh Boone
# 2021-09-22                         NaN
# 2021-09-22                         NaN
#
#                                                          cast  \
# date_added
# 2021-09-24                      Apthon Corbin, Louis Gonzales
# 2021-09-24  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...
# 2021-09-24  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...
# 2021-09-22                                       Matt Beisner
# ...

# %%
movie["2019-12"]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18108\2238263617.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   movie["2019-12"]
#            show_id     type  \
# date_added
# 2019-12-27    s601    Movie
# 2019-12-26    s602    Movie
# 2019-12-20    s603    Movie
# 2019-12-20    s604    Movie
# 2019-12-20    s605    Movie
# 2019-12-20    s606  TV Show
# 2019-12-20    s607    Movie
# 2019-12-13    s608    Movie
# 2019-12-13    s609    Movie
# 2019-12-06    s610    Movie
# 2019-12-06    s611  TV Show
# 2019-12-05    s612    Movie
# 2019-12-03    s613  TV Show
# 2019-12-03    s614    Movie
# 2019-12-01    s615  TV Show
# 2019-12-01    s616    Movie
# 2019-12-01    s617    Movie
# 2019-12-01    s618  TV Show
# 2019-12-01    s619    Movie
# 2019-12-01    s620    Movie
# 2019-12-01    s621    Movie
# ...

# %% [markdown]
# ## Working with Indexes

# %%
movie["2019-12"].release_year.mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18108\827227219.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   movie["2019-12"].release_year.mean()
# 2016.12

# %%
movie["2019-07-05":"2019-12-10"]
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18108\2153707565.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   movie["2019-07-05":"2019-12-10"]
#            show_id     type                                 title  \
# date_added
# 2019-12-06    s610    Movie  Forky Asks a Question: What is Love?
# 2019-12-06    s611  TV Show            One Day at Disney (Shorts)
# 2019-12-05    s612    Movie        Marvel Studios' Thor: Ragnarok
# 2019-12-03    s613  TV Show                 Disney The Lion Guard
# 2019-12-03    s614    Movie                     One Day at Disney
# ...            ...      ...                                   ...
# 2019-10-01   s1361  TV Show                             Smart Guy
# 2019-10-01   s1362    Movie              The Cat from Outer Space
# 2019-10-01   s1363    Movie             The Great Mouse Detective
# ...

# %%
t=pd.to_datetime("7/22/2019")
t
# Out:
# Timestamp('2019-07-22 00:00:00')

# %%
movie.loc[movie.index>=t,:]
# Out:
#            show_id     type                           title  \
# date_added
# 2021-09-24      s1    Movie                   A Spark Story
# 2021-09-24      s2    Movie                  Spooky Buddies
# 2021-09-24      s3    Movie          The Fault in Our Stars
# 2021-09-22      s4  TV Show                 Dog: Impossible
# 2021-09-22      s5  TV Show  Spidey And His Amazing Friends
# ...            ...      ...                             ...
# 2019-10-01   s1361  TV Show                       Smart Guy
# 2019-10-01   s1362    Movie        The Cat from Outer Space
# 2019-10-01   s1363    Movie       The Great Mouse Detective
# 2019-10-01   s1364    Movie          The Sword in the Stone
# 2019-10-01   s1365    Movie                 Those Calloways
#
#                                             director  \
# date_added
# 2021-09-24                Jason Sterman, Leanne Dare
# 2021-09-24                              Robert Vince
# 2021-09-24                                Josh Boone
# ...

# %% [markdown]
# ## Dating the Data Set

# %%
movie1=pd.read_csv(r'C:\Users\Lenovo\Downloads\disney_plus_titles.csv',sep=";")

# %%
movie1.head()
# Out:
#   show_id,type,title,director,cast,country,date_added,release_year,rating,duration,listed_in,description
# 0  s1,Movie,A Spark Story,"Jason Sterman, Leanne ...
# 1  s2,Movie,Spooky Buddies,Robert Vince,"Tucker A...
# 2  s3,Movie,The Fault in Our Stars,Josh Boone,"Sh...
# 3  s4,TV Show,Dog: Impossible,,Matt Beisner,Unite...
# 4  s5,TV Show,Spidey And His Amazing Friends,,"Be...

# %%
dates=pd.date_range(start="2019", 
                    end="2019", 
                    freq="B") 
dates
# Out:
# DatetimeIndex(['2019-01-01'], dtype='datetime64[ns]', freq='B')

# %%
movie1.head()
# Out:
#   show_id,type,title,director,cast,country,date_added,release_year,rating,duration,listed_in,description
# 0  s1,Movie,A Spark Story,"Jason Sterman, Leanne ...
# 1  s2,Movie,Spooky Buddies,Robert Vince,"Tucker A...
# 2  s3,Movie,The Fault in Our Stars,Josh Boone,"Sh...
# 3  s4,TV Show,Dog: Impossible,,Matt Beisner,Unite...
# 4  s5,TV Show,Spidey And His Amazing Friends,,"Be...

# %%
movie1.index
# Out:
# RangeIndex(start=0, stop=1368, step=1)
