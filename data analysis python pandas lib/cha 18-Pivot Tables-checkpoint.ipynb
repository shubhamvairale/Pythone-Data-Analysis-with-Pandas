# %% [markdown]
# # Pivot Tables

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(
    {"class":list("ABC")*4,
     "lesson":["math","stat"]*6,
     "sex":list("MFMM")*3,
     "sibling":[1,2,3]*4,
     "score":np.arange(40,100,5)})

# %%
df
# Out:
#    class lesson sex  sibling  score
# 0      A   math   M        1     40
# 1      B   stat   F        2     45
# 2      C   math   M        3     50
# 3      A   stat   M        1     55
# 4      B   math   M        2     60
# 5      C   stat   F        3     65
# 6      A   math   M        1     70
# 7      B   stat   M        2     75
# 8      C   math   M        3     80
# 9      A   stat   F        1     85
# 10     B   math   M        2     90
# 11     C   stat   M        3     95

# %%
df.groupby("lesson")["score"].mean()
# Out:
# lesson
# math    65.0
# stat    70.0
# Name: score, dtype: float64

# %%
df.groupby(
    ["lesson",
     "class"])[
    "score"].aggregate("mean").unstack()
# Out:
# class      A     B     C
# lesson
# math    55.0  75.0  65.0
# stat    70.0  60.0  80.0

# %%
df.pivot_table(
    "score",
    index="lesson",
    columns="class")
# Out:
# class    A   B   C
# lesson
# math    55  75  65
# stat    70  60  80

# %%
df.pivot_table(
    ["sibling","score"],
    index=["class","lesson"],
    columns="sex")
# Out:
#              score       sibling
# sex              F     M       F    M
# class lesson
# A     math     NaN  55.0     NaN  1.0
#       stat    85.0  55.0     1.0  1.0
# B     math     NaN  75.0     NaN  2.0
#       stat    45.0  75.0     2.0  2.0
# C     math     NaN  65.0     NaN  3.0
#       stat    65.0  95.0     3.0  3.0

# %%
df.pivot_table(
    ["sibling","score"],
    index=["class","lesson"],
    columns="sex",margins=True)
# Out:
#              score                  sibling
# sex              F          M   All       F    M  All
# class lesson
# A     math     NaN  55.000000  55.0     NaN  1.0  1.0
#       stat    85.0  55.000000  70.0     1.0  1.0  1.0
# B     math     NaN  75.000000  75.0     NaN  2.0  2.0
#       stat    45.0  75.000000  60.0     2.0  2.0  2.0
# C     math     NaN  65.000000  65.0     NaN  3.0  3.0
#       stat    65.0  95.000000  80.0     3.0  3.0  3.0
# All           65.0  68.333333  67.5     2.0  2.0  2.0

# %%
df.pivot_table(
    ["sibling","score"],
    index=["class","lesson"],
    columns="sex",fill_value=0)
# Out:
#              score     sibling
# sex              F   M       F  M
# class lesson
# A     math       0  55       0  1
#       stat      85  55       1  1
# B     math       0  75       0  2
#       stat      45  75       2  2
# C     math       0  65       0  3
#       stat      65  95       3  3

# %% [markdown]
# ## Multi-level pivot tables

# %%
sib=pd.cut(df["sibling"],[0,2,3])

# %%
df.pivot_table("score",
               ["lesson",sib],
               "class",fill_value=0)
# Out:
# class            A   B   C
# lesson sibling
# math   (0, 2]   55  75   0
#        (2, 3]    0   0  65
# stat   (0, 2]   70  60   0
#        (2, 3]    0   0  80

# %%
df.pivot_table(
    "score",
    index="lesson",
    columns="class")
# Out:
# class    A   B   C
# lesson
# math    55  75  65
# stat    70  60  80

# %%
df.pivot_table(
    index="lesson",
    columns="class",
    aggfunc="sum")
# Out:
#        score           sibling
# class      A    B    C       A  B  C
# lesson
# math     110  150  130       2  4  6
# stat     140  120  160       2  4  6

# %%
df.pivot_table(
    index="lesson",
    columns="class",
    aggfunc={"sibling":"max",
             "score":"sum"})
# Out:
#        score           sibling
# class      A    B    C       A  B  C
# lesson
# math     110  150  130       1  2  3
# stat     140  120  160       1  2  3

# %% [markdown]
# ## Cross-Tabulations: Crosstab

# %%
pd.crosstab(df.sibling,df.lesson)
# Out:
# lesson   math  stat
# sibling
# 1           2     2
# 2           2     2
# 3           2     2

# %%
pd.crosstab([df.sibling, df.lesson], df.sex)
# Out:
# sex             F  M
# sibling lesson
# 1       math    0  2
#         stat    1  1
# 2       math    0  2
#         stat    1  1
# 3       math    0  2
#         stat    1  1

# %%
sal=pd.read_csv(r'C:\Users\Lenovo\Downloads\data.txt')

# %%
sal.head()
# Out:
#    year  month  day gender  salary
# 0  1969      1  1.0      F   80080
# 1  1969      1  1.0      M   80800
# 2  1969      1  2.0      F   80800
# 3  1969      1  2.0      M   80508
# 4  1969      1  3.0      F   80580

# %%
sal["ten_year"]=10*(sal["year"]//10)
sal.pivot_table("salary",
                   index="ten_year",
                   columns="gender",
                   aggfunc="sum")
# Out:
# gender             F           M
# ten_year
# 1960       163649314    81647592
# 1970      1325485712  1209918856
# 1980       778191667   684503398
# 1990       281577378   169459904
# 2000       317395837  2007706953
# 19780      207138765   135439922
# 19880       69489240   133710284
# 19980       24215660     5056691
# 20080       23174626     8495603

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set() #For style

# %%
sal.pivot_table("salary",
                   index="year",
                   columns="gender",
                   aggfunc="sum").plot()
plt.ylabel("Annual total salary")
# Out:
# Text(0, 0.5, 'Annual total salary')
