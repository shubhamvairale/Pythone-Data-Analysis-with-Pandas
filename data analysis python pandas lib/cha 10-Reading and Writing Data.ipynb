# %% [markdown]
# # Data Reading & Writting in Pandas

# %%
import pandas as pd  
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv')
df
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 0            412    250   48.3  5.15     NaN     1    won      v India
# 1            680    165   48.0  3.43   251.0     2   lost   v Pakistan
# 2            413    157   48.5  3.21   168.0     2   lost      v India
# 3            681    167   43.4  3.82     NaN     1    won   v Pakistan
# 4            117    198   40.0  4.95   306.0     2   lost  v Australia
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1291         549  340/7   50.0  6.80     NaN     1   lost    v England
# 1292         979  341/7   49.3  6.88   341.0     2    won   v Pakistan
# 1293        1296  120/8   33.0  3.63   211.0     2      -    v Ireland
# 1294         550  193/6   31.5  6.06   352.0     2      -    v England
# 1295         980  351/9   50.0  7.02     NaN     1      -   v Pakistan
#
#           Ground   Start Date    Match_ID      Country  Country_ID
# ...

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv', sep=",")
df
# Out:
#       Unnamed: 0  Score  Overs   RPO  Target  Inns Result   Opposition  \
# 0            412    250   48.3  5.15     NaN     1    won      v India
# 1            680    165   48.0  3.43   251.0     2   lost   v Pakistan
# 2            413    157   48.5  3.21   168.0     2   lost      v India
# 3            681    167   43.4  3.82     NaN     1    won   v Pakistan
# 4            117    198   40.0  4.95   306.0     2   lost  v Australia
# ...          ...    ...    ...   ...     ...   ...    ...          ...
# 1291         549  340/7   50.0  6.80     NaN     1   lost    v England
# 1292         979  341/7   49.3  6.88   341.0     2    won   v Pakistan
# 1293        1296  120/8   33.0  3.63   211.0     2      -    v Ireland
# 1294         550  193/6   31.5  6.06   352.0     2      -    v England
# 1295         980  351/9   50.0  7.02     NaN     1      -   v Pakistan
#
#           Ground   Start Date    Match_ID      Country  Country_ID
# ...

# %%
df=pd.read_table(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv',
                 sep=",",
                 header=None)
df
# Out:
#           0      1      2     3       4     5       6           7   \
# 0        NaN  Score  Overs   RPO  Target  Inns  Result  Opposition
# 1      412.0    250   48.3  5.15     NaN     1     won     v India
# 2      680.0    165   48.0  3.43     251     2    lost  v Pakistan
# 3      413.0    157   48.5  3.21     168     2    lost     v India
# 4      681.0    167   43.4  3.82     NaN     1     won  v Pakistan
# ...      ...    ...    ...   ...     ...   ...     ...         ...
# 1292   549.0  340/7   50.0  6.80     NaN     1    lost   v England
# 1293   979.0  341/7   49.3  6.88     341     2     won  v Pakistan
# 1294  1296.0  120/8   33.0  3.63     211     2       -   v Ireland
# 1295   550.0  193/6   31.5  6.06     352     2       -   v England
# 1296   980.0  351/9   50.0  7.02     NaN     1       -  v Pakistan
#
#               8            9           10           11          12
# 0         Ground   Start Date    Match_ID      Country  Country_ID
# ...

# %%
df=pd.read_table(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv',
                 sep=",",
                 header=None, 
                 names=["Ground","Score","Country"])
df
# Out:
#                                                                                   Ground  \
# NaN    Score Overs RPO  Target Inns Result Opposition Ground     Start Date     Match_ID
# 412.0  250   48.3  5.15 NaN    1    won    v India    Kolkata    3 Jan 2013   ODI # 3315
# 680.0  165   48.0  3.43 251    2    lost   v Pakistan Kolkata    3 Jan 2013   ODI # 3315
# 413.0  157   48.5  3.21 168    2    lost   v India    Delhi      6 Jan 2013   ODI # 3316
# 681.0  167   43.4  3.82 NaN    1    won    v Pakistan Delhi      6 Jan 2013   ODI # 3316
# ...                                                                                  ...
# 549.0  340/7 50.0  6.80 NaN    1    lost   v England  Nottingham 17 May 2019  ODI # 4138
# 979.0  341/7 49.3  6.88 341    2    won    v Pakistan Nottingham 17 May 2019  ODI # 4138
# 1296.0 120/8 33.0  3.63 211    2    -      v Ireland  Belfast    19 May 2019  ODI # 4139
# ...

# %%
df=pd.read_table(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv',
                 sep=",",header=None, 
                 names=["Ground","Score","Country"])
df
# Out:
#                                                                                   Ground  \
# NaN    Score Overs RPO  Target Inns Result Opposition Ground     Start Date     Match_ID
# 412.0  250   48.3  5.15 NaN    1    won    v India    Kolkata    3 Jan 2013   ODI # 3315
# 680.0  165   48.0  3.43 251    2    lost   v Pakistan Kolkata    3 Jan 2013   ODI # 3315
# 413.0  157   48.5  3.21 168    2    lost   v India    Delhi      6 Jan 2013   ODI # 3316
# 681.0  167   43.4  3.82 NaN    1    won    v Pakistan Delhi      6 Jan 2013   ODI # 3316
# ...                                                                                  ...
# 549.0  340/7 50.0  6.80 NaN    1    lost   v England  Nottingham 17 May 2019  ODI # 4138
# 979.0  341/7 49.3  6.88 341    2    won    v Pakistan Nottingham 17 May 2019  ODI # 4138
# 1296.0 120/8 33.0  3.63 211    2    -      v Ireland  Belfast    19 May 2019  ODI # 4139
# ...

# %%
df3=pd.read_table(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv',
                  sep=",", 
                  skiprows=[0,2])
df3
# Out:
#        412    250  48.3  5.15  Unnamed: 4  1   won      v India     Kolkata  \
# 0      413    157  48.5  3.21       168.0  2  lost      v India       Delhi
# 1      681    167  43.4  3.82         NaN  1   won   v Pakistan       Delhi
# 2      117    198  40.0  4.95       306.0  2  lost  v Australia   Melbourne
# 3     1076  305/5  50.0  6.10         NaN  1   won  v Sri Lanka   Melbourne
# 4      682  316/9  50.0  6.32       326.0  2  lost    v England      Rajkot
# ...    ...    ...   ...   ...         ... ..   ...          ...         ...
# 1289   549  340/7  50.0  6.80         NaN  1  lost    v England  Nottingham
# 1290   979  341/7  49.3  6.88       341.0  2   won   v Pakistan  Nottingham
# 1291  1296  120/8  33.0  3.63       211.0  2     -    v Ireland     Belfast
# 1292   550  193/6  31.5  6.06       352.0  2     -    v England       Leeds
# 1293   980  351/9  50.0  7.02         NaN  1     -   v Pakistan       Leeds
#
#        3 Jan 2013  ODI # 3315     Pakistan   7
# ...

# %%
df3=pd.read_table(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv',
                  sep=",", 
                  skiprows=[0,2],
                  usecols=[0,1])
df3
# Out:
#        412    250
# 0      413    157
# 1      681    167
# 2      117    198
# 3     1076  305/5
# 4      682  316/9
# ...    ...    ...
# 1289   549  340/7
# 1290   979  341/7
# 1291  1296  120/8
# 1292   550  193/6
# 1293   980  351/9
#
# [1294 rows x 2 columns]

# %%
df3=pd.read_table(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv',
                  sep=",", 
                  skiprows=[0,2],
                  usecols=[0,1],
                  nrows=3)
df3
# Out:
#    412  250
# 0  413  157
# 1  681  167
# 2  117  198

# %% [markdown]
# ## Writing Data

# %%
df=pd.read_csv(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv',sep="\t")
df
# Out:
#      ,"Score","Overs","RPO","Target","Inns","Result","Opposition","Ground","Start Date","Match_ID","Country","Country_ID"
# 0     412,"250","48.3","5.15","","1","won","v India"...
# 1     680,"165","48.0","3.43","251","2","lost","v Pa...
# 2     413,"157","48.5","3.21","168","2","lost","v In...
# 3     681,"167","43.4","3.82","","1","won","v Pakist...
# 4     117,"198","40.0","4.95","306","2","lost","v Au...
# ...                                                 ...
# 1291  549,"340/7","50.0","6.80","","1","lost","v Eng...
# 1292  979,"341/7","49.3","6.88","341","2","won","v P...
# 1293  1296,"120/8","33.0","3.63","211","2","-","v Ir...
# 1294  550,"193/6","31.5","6.06","352","2","-","v Eng...
# 1295  980,"351/9","50.0","7.02","","1","-","v Pakist...
#
# [1296 rows x 1 columns]

# %%
df.to_csv(r'C:\Users\Lenovo\Downloads\ODI_DATASET.csv')
df
# Out:
#      ,"Score","Overs","RPO","Target","Inns","Result","Opposition","Ground","Start Date","Match_ID","Country","Country_ID"
# 0     412,"250","48.3","5.15","","1","won","v India"...
# 1     680,"165","48.0","3.43","251","2","lost","v Pa...
# 2     413,"157","48.5","3.21","168","2","lost","v In...
# 3     681,"167","43.4","3.82","","1","won","v Pakist...
# 4     117,"198","40.0","4.95","306","2","lost","v Au...
# ...                                                 ...
# 1291  549,"340/7","50.0","6.80","","1","lost","v Eng...
# 1292  979,"341/7","49.3","6.88","341","2","won","v P...
# 1293  1296,"120/8","33.0","3.63","211","2","-","v Ir...
# 1294  550,"193/6","31.5","6.06","352","2","-","v Eng...
# 1295  980,"351/9","50.0","7.02","","1","-","v Pakist...
#
# [1296 rows x 1 columns]
